# %%
from __future__ import print_function
import json
import numpy as np
import cv2
import matplotlib.pyplot as plt
from evaluate.lane import LaneEval
# %matplotlib inline

# %% [markdown]
# Suppose we have two json files, one is the ground truth and the other is the prediction.
#
# We assume that each line in prediction json file is corresponding to the ground truth json,
# which means both lines are related to the same image.

# %%
train_path = '/data2/tusimple_lane_data/train/'
test_path = '/data2/tusimple_lane_data/test/'

# %%
#json_pred = [json.loads(line) for line in open('pred.json').readlines()]
#json_gt = [json.loads(line) for line in open('label_data.json')]

#json_pred = [json.loads(line) for line in open('test_pred_sample.json').readlines()]
#json_gt = [json.loads(line) for line in open('test_gt_sample.json')]

# %%
# load prediction for training data
json_pred = [json.loads(line) for line in open('label_data_0313_pred.json').readlines()]
# load training gt
json_gt = [json.loads(line) for line in open('label_data_0313.json')]

# %%
type(json_pred), len(json_pred)
# Out:
# (list, 2858)

# %%
pred, gt = json_pred[0], json_gt[0]
pred_lanes = pred['lanes']
run_time = pred['run_time']
gt_lanes = gt['lanes']
y_samples = gt['h_samples']
raw_file = gt['raw_file']

# %% [markdown]
# First let's check out the image.

# %%
raw_file
# Out:
# 'clips/0313-1/6040/20.jpg'

# %%
raw_file
raw_file_fname = train_path + raw_file
raw_file_fname
# Out:
# '/data2/tusimple_lane_data/train/clips/0313-1/6040/20.jpg'

# %%
img = plt.imread(raw_file_fname)
plt.imshow(img)
plt.show()

# %% [markdown]
# Then, we show how to use `y_samples`.

# %%
gt_lanes_vis = [[(x, y) for (x, y) in zip(lane, y_samples) if x >= 0] for lane in gt_lanes]
img_vis = img.copy()

for lane in gt_lanes_vis:
    for pt in lane:
        cv2.circle(img_vis, pt, radius=5, color=(0, 255, 0))

plt.imshow(img_vis)
plt.show()

# %%
type(gt_lanes_vis), len(gt_lanes_vis)
# Out:
# (list, 4)

# %%
gt_lanes_vis
# Out:
# [[(632, 280),
#   (625, 290),
#   (617, 300),
#   (609, 310),
#   (601, 320),
#   (594, 330),
#   (586, 340),
#   (578, 350),
#   (570, 360),
#   (563, 370),
#   (555, 380),
#   (547, 390),
#   (539, 400),
#   (532, 410),
#   (524, 420),
#   (516, 430),
#   (508, 440),
#   (501, 450),
#   (493, 460),
#   (485, 470),
#   (477, 480),
#   (469, 490),
#   (462, 500),
#   (454, 510),
#   (446, 520),
#   (438, 530),
#   (431, 540),
#   (423, 550),
#   (415, 560),
#   (407, 570),
#   (400, 580),
#   (392, 590),
#   (384, 600),
#   (376, 610),
#   (369, 620),
#   (361, 630),
#   (353, 640),
#   (345, 650),
#   (338, 660),
#   (330, 670),
#   (322, 680),
#   (314, 690),
#   (307, 700),
#   (299, 710)],
#  [(719, 280),
#   (734, 290),
#   (748, 300),
#   (762, 310),
#   (777, 320),
#   (791, 330),
#   (805, 340),
#   (820, 350),
#   (834, 360),
#   (848, 370),
#   (863, 380),
#   (877, 390),
#   (891, 400),
#   (906, 410),
#   (920, 420),
#   (934, 430),
#   (949, 440),
#   (963, 450),
#   (978, 460),
#   (992, 470),
#   (1006, 480),
#   (1021, 490),
#   (1035, 500),
#   (1049, 510),
#   (1064, 520),
#   (1078, 530),
#   (1092, 540),
#   (1107, 550),
#   (1121, 560),
#   (1135, 570),
#   (1150, 580),
#   (1164, 590),
#   (1178, 600),
#   (1193, 610),
#   (1207, 620),
#   (1221, 630),
#   (1236, 640),
#   (1250, 650),
#   (1265, 660)],
#  [(532, 290),
#   (503, 300),
#   (474, 310),
#   (445, 320),
#   (416, 330),
#   (387, 340),
#   (358, 350),
#   (329, 360),
#   (300, 370),
#   (271, 380),
#   (241, 390),
#   (212, 400),
#   (183, 410),
#   (154, 420),
#   (125, 430),
#   (96, 440),
#   (67, 450),
#   (38, 460),
#   (9, 470)],
#  [(781, 270),
#   (822, 280),
#   (862, 290),
#   (903, 300),
#   (944, 310),
#   (984, 320),
#   (1025, 330),
#   (1066, 340),
#   (1107, 350),
#   (1147, 360),
#   (1188, 370),
#   (1229, 380),
#   (1269, 390)]]

# %% [markdown]
# Then, we show the ground truth and the prediction example.
#
# The ground truth is shown in green and the prediction is shown in blue. As we can see the prediction is not perfect.

# %%
gt_lanes_vis = [[(x, y) for (x, y) in zip(lane, y_samples) if x >= 0] for lane in gt_lanes]
pred_lanes_vis = [[(x, y) for (x, y) in zip(lane, y_samples) if x >= 0] for lane in pred_lanes]
img_vis = img.copy()

for lane in gt_lanes_vis:
    cv2.polylines(img_vis, np.int32([lane]), isClosed=False, color=(0,255,0), thickness=5)
for lane in pred_lanes_vis:
    cv2.polylines(img_vis, np.int32([lane]), isClosed=False, color=(0,0,255), thickness=2)

plt.imshow(img_vis)
plt.show()

# %% [markdown]
# Now we can use the tool to evaluate the prediction based on the data.
#
# The evaluation metric is described on the benchmark website.

# %%
np.random.shuffle(pred_lanes)
# Overall Accuracy, False Positive Rate, False Negative Rate
print(LaneEval.bench(pred_lanes, gt_lanes, y_samples, run_time))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-35-1aa7296c698d> in <module>()
#       1 np.random.shuffle(pred_lanes)
#       2 # Overall Accuracy, False Positive Rate, False Negative Rate
# ----> 3 print(LaneEval.bench(pred_lanes, gt_lanes, y_samples, run_time))
#
# /data/code/tusimple_lane_dect/example/evaluate/lane.py in bench(pred, gt, y_samples, running_time)
#      29     def bench(pred, gt, y_samples, running_time):
#      30         if any(len(p) != len(y_samples) for p in pred):
# ---> 31             raise Exception('Format of lanes error.')
#      32         if running_time > 200:
#      33             return 0., 0., 1.
#
# Exception: Format of lanes error.
